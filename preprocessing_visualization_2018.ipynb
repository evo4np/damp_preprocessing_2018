# %% [markdown]
# <a href="https://colab.research.google.com/github/evo4np/damp_preprocessing_2018/blob/master/preprocessing_visualization_2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preprocessing and visualization of 2018 Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
#Import as Dataframe
one = 'https://raw.githubusercontent.com/evo4np/damp_preprocessing_2018/master/Stockholm%20E4%20Skonertva%CC%88gen.csv'
two = 'https://raw.githubusercontent.com/evo4np/damp_preprocessing_2018/master/Stockholm%20E4%3AE20%20Lilla%20Essingen.csv'
three = 'https://raw.githubusercontent.com/evo4np/damp_preprocessing_2018/master/Stockholm%20Folkungagatan%2057.csv'
four = 'https://raw.githubusercontent.com/evo4np/damp_preprocessing_2018/master/Stockholm%20Hornsgatan%20108%20Gata.csv'
five = 'https://raw.githubusercontent.com/evo4np/damp_preprocessing_2018/master/Stockholm%20Hornsgatan%20108%20Tak.csv'
six = 'https://raw.githubusercontent.com/evo4np/damp_preprocessing_2018/master/Stockholm%20Hornsgatan%2085%20Gatuniva%CC%8A.csv'

# %%
station_157993 = pd.read_csv(one ,sep=';', skiprows=11, parse_dates=['Start'], index_col= 'Start')
station_18644 = pd.read_csv(two ,sep=';', skiprows=12, parse_dates=['Start'], index_col= 'Start')
station_155527 = pd.read_csv(three,sep=';', skiprows=11,parse_dates=['Start'], index_col= 'Start')
station_159403 = pd.read_csv(four,sep=';', skiprows=16,parse_dates=['Start'], index_col= 'Start')
station_18638 = pd.read_csv(five,sep=';' ,skiprows=11,parse_dates=['Start'], index_col= 'Start')
station_18639 = pd.read_csv(six ,sep=';' ,skiprows=11,parse_dates=['Start'], index_col= 'Start')

# %%
station_157993.head()
# Out:
#                                  Slut  ...  PM10 (4209)
# Start                                  ...
# 2018-01-01 00:00:00  2018-01-01 01:00  ...         58.9
# 2018-01-01 01:00:00  2018-01-01 02:00  ...         15.7
# 2018-01-01 02:00:00  2018-01-01 03:00  ...          8.6
# 2018-01-01 03:00:00  2018-01-01 04:00  ...          9.1
# 2018-01-01 04:00:00  2018-01-01 05:00  ...          6.9
#
# [5 rows x 4 columns]

# %%
station_157993.describe()
# Out:
#         NO2 (4207)  NOX as NO2 (4208)  PM10 (4209)
# count  8752.000000        8755.000000  8693.000000
# mean     29.291419          61.110177    19.910503
# std      27.102107          71.151257    24.577628
# min       0.100000           0.900000    -3.000000
# 25%       6.000000           8.000000     6.200000
# 50%      20.500000          31.700000    12.100000
# 75%      47.000000          91.100000    23.700000
# max     156.700000         504.900000   394.600000

# %%
station_18644.head()
# Out:
#                                  Slut  NO2 (344)  ...  PM10 (342)  PM2.5 (343)
# Start                                             ...
# 2018-01-01 00:00:00  2018-01-01 01:00       38.4  ...        39.6         25.9
# 2018-01-01 01:00:00  2018-01-01 02:00       49.9  ...        20.3          9.5
# 2018-01-01 02:00:00  2018-01-01 03:00       41.9  ...        14.5          2.9
# 2018-01-01 03:00:00  2018-01-01 04:00       40.4  ...        13.9          2.4
# 2018-01-01 04:00:00  2018-01-01 05:00       35.3  ...        13.3          4.3
#
# [5 rows x 5 columns]

# %%
station_18644.describe()
# Out:
#          NO2 (344)  NOX as NO2 (345)   PM10 (342)  PM2.5 (343)
# count  8587.000000       8587.000000  8546.000000  8452.000000
# mean     36.204495         73.599243    26.413585     6.153064
# std      21.701772         61.666964    25.427863     4.951040
# min       1.600000          2.700000    -2.500000    -3.000000
# 25%      19.900000         30.800000    11.400000     2.800000
# 50%      32.100000         55.900000    18.400000     5.300000
# 75%      49.100000         97.800000    31.700000     8.500000
# max     154.300000        586.500000   264.300000    81.000000

# %%
def plot_df(df, x, y, dpi=100):
    plt.figure(figsize=(20,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca()
    plt.show()

# %% [markdown]
# **N02 Distribution for Station 157993- Stockholm E4 Skonertvägen**

# %%
plot_df(station_157993, x=station_157993.index, y=station_157993['NO2 (4207)'])

# %% [markdown]
# **NOX as NO2 Distribution for Station 157993- Stockholm E4 Skonertvägen**

# %%
plot_df(station_157993, x=station_157993.index, y=station_157993['NOX as NO2 (4208)'])

# %% [markdown]
# **PM10 Distribution  for Station 157993- Stockholm E4 Skonertvägen**

# %%
plot_df(station_157993, x=station_157993.index, y=station_157993['PM10 (4209)'])
